# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthibala07/Machine-learning-models-unsupervised/blob/main/KMeans_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import plotly.graph_objs as go
from sklearn.cluster import KMeans

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('/content/Iris_1.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
x=data.iloc[:,[2,4]].values
x
# Out:
# array([[3.5, 0.2],
#        [3. , 0.2],
#        [3.2, 0.2],
#        [3.1, 0.2],
#        [3.6, 0.2],
#        [3.9, 0.4],
#        [3.4, 0.3],
#        [3.4, 0.2],
#        [2.9, 0.2],
#        [3.1, 0.1],
#        [3.7, 0.2],
#        [3.4, 0.2],
#        [3. , 0.1],
#        [3. , 0.1],
#        [4. , 0.2],
#        [4.4, 0.4],
#        [3.9, 0.4],
#        [3.5, 0.3],
#        [3.8, 0.3],
#        [3.8, 0.3],
#        [3.4, 0.2],
#        [3.7, 0.4],
#        [3.6, 0.2],
#        [3.3, 0.5],
#        [3.4, 0.2],
#        [3. , 0.2],
#        [3.4, 0.4],
#        [3.5, 0.2],
#        [3.4, 0.2],
#        [3.2, 0.2],
#        [3.1, 0.2],
#        [3.4, 0.4],
#        [4.1, 0.1],
#        [4.2, 0.2],
#        [3.1, 0.1],
#        [3.2, 0.2],
#        [3.5, 0.2],
#        [3.1, 0.1],
#        [3. , 0.2],
#        [3.4, 0.2],
#        [3.5, 0.3],
#        [2.3, 0.3],
#        [3.2, 0.2],
#        [3.5, 0.6],
#        [3.8, 0.4],
#        [3. , 0.3],
#        [3.8, 0.2],
# ...

# %%
w=[]
for i in range(1,11):
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=0)
  kmeans.fit(x)
  w.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),w)
plt.title('Elbow Method')
plt.xlabel('no.of.clusters')
plt.ylabel('w')
plt.show()

# %%
kmeansmodel=KMeans(n_clusters=3,init='k-means++',random_state=0)
y_kmeans=kmeansmodel.fit_predict(x)

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 50,c = 'red', label = 'Cluster 1',edgecolor='black')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 50 ,c = 'blue', label = 'Cluster 2',edgecolor='black')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 50, c = 'green', label = 'Cluster 3',edgecolor='black')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],marker='*', s = 200, c = 'black', label = 'Centroids',edgecolor='black')
plt.title('petalwidth')
plt.xlabel('petallength')
plt.ylabel('species')
plt.legend()
plt.show()
